# %% [markdown]
# ### Day 25: 30 Days of python programming
# ### Topic : pandas
# ### 💻 Exercise: Level 1

# %% [markdown]
# 1. Read the hacker_news.csv file from data directory

# %%
import pandas as pd
df = pd.read_csv("hacker_news.csv")
df = pd.DataFrame(df)
print(df)
print(df.shape)
print(df.columns)
# Out:
#              id                                              title  \
# 0      12224879                          Interactive Dynamic Video
# 1      11964716  Florida DJs May Face Felony for April Fools' W...
# 2      11919867       Technology ventures: From Idea to Enterprise
# 3      10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4      10482257  Title II kills investment? Comcast and other I...
# ...         ...                                                ...
# 20094  12379592  How Purism Avoids Intels Active Management Tec...
# 20095  10339284          YC Application Translated and Broken Down
# 20096  10824382  Microkernels are slow and Elvis didn't do no d...
# 20097  10739875                      How Product Hunt really works
# 20098  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 0                http://www.interactivedynamicvideo.com/         386
# ...

# %% [markdown]
# 2. Get the first five rows

# %%
print(df.head(5))
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  11964716  Florida DJs May Face Felony for April Fools' W...
# 2  11919867       Technology ventures: From Idea to Enterprise
# 3  10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4  10482257  Title II kills investment? Comcast and other I...
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://www.thewire.com/entertainment/2013/04/f...           2
# 2  https://www.amazon.com/Technology-Ventures-Ent...           3
# 3  http://www.nytimes.com/2007/11/07/movies/07ste...           8
# 4  http://arstechnica.com/business/2015/10/comcas...          53
#
#    num_comments      author       created_at
# 0            52    ne0phyte   8/4/2016 11:52
# 1             1    vezycash  6/23/2016 22:20
# 2             1     hswarna   6/17/2016 0:01
# ...

# %% [markdown]
# 3. Get the last five rows

# %%
print(df.tail(5))
# Out:
#              id                                              title  \
# 20094  12379592  How Purism Avoids Intels Active Management Tec...
# 20095  10339284          YC Application Translated and Broken Down
# 20096  10824382  Microkernels are slow and Elvis didn't do no d...
# 20097  10739875                      How Product Hunt really works
# 20098  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 20094  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20095  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20096  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20097  https://medium.com/@benjiwheeler/how-product-h...         695
# 20098              https://github.com/jmcarp/robobrowser         182
#
#        num_comments         author        created_at
# 20094             6  AdmiralAsshat    8/29/2016 2:22
# ...

# %%
import pandas as pd
data = [
    ['Asabeneh', 'Finland', 'Helsink'], 
    ['David', 'UK', 'London'],
    ['John', 'Sweden', 'Stockholm']
]
df = pd.DataFrame(data, columns=['Names','Country','City'], index=[1,2,3])
print(df)
# Out:
#       Names  Country       City
# 1  Asabeneh  Finland    Helsink
# 2     David       UK     London
# 3      John   Sweden  Stockholm

# %% [markdown]
# 4. Get the title column as pandas series

# %%
print(df.title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-ac02497685b3> in <module>
# ----> 1 print(df.title)
#
# c:\Users\Dell\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'title'

# %% [markdown]
# 5. Count the number of rows and columns

# %%
print(df.count())
print("Number of rows: ", df.shape[0])
print("Number of columns: ", df.shape[1])
# Out:
# id              20099
# title           20099
# url             17659
# num_points      20099
# num_comments    20099
# author          20099
# created_at      20099
# dtype: int64
# Number of rows:  20099
# Number of columns:  7

# %% [markdown]
#  **Filter the titles which contain python**

# %%
df_title =df[df["title"].str.contains("Python" or "python" or "PYTHON")]
print(df_title["title"])

# Another method
def title_with_python():
    n = 1
    for title in df.title:
        if ("Python" or "python" or "PYTHON") in title:  
            print(n, title)
            n +=1
    return " "
twp = title_with_python()
print(twp)
# Out:
# 102                    From Python to Lua: Why We Switched
# 103              Ubuntu 16.04 LTS to Ship Without Python 2
# 144      Create a GUI Application Using Qt and Python i...
# 196      How I Solved GCHQ's Xmas Card with Python and ...
# 436      Unikernel Power Comes to Java, Node.js, Go, an...
#                                ...
# 19597    David Beazley  Python Concurrency from the Gro...
# 19852      Ask HN: How to automate Python apps deployment?
# 19862                            Moving Away from Python 2
# 19980                        Python vs. Julia Observations
# 19998    Show HN: Decorating: Animated pulsed for your ...
# Name: title, Length: 149, dtype: object
# 1 From Python to Lua: Why We Switched
# 2 Ubuntu 16.04 LTS to Ship Without Python 2
# 3 Create a GUI Application Using Qt and Python in Minutes
# 4 How I Solved GCHQ's Xmas Card with Python and Pycosat. (Explanation and Source)
# 5 Unikernel Power Comes to Java, Node.js, Go, and Python Apps
# ...

# %% [markdown]
# **Filter the titles which contain JavaScript**

# %%
df_title =df[df["title"].str.contains("JavaScript" or "javascript" or "JAVASCRIPT")]
print(df_title["title"])

# Another method
def title_with_JavaScript():
    n = 1
    for title in df.title:
        if ("JavaScript" or "javascript" or "JAVASCRIPT") in title:  
            print(n, title)
            n +=1
    return " "
twj = title_with_JavaScript()
print(twj)
# Out:
# 267       Show HN: Hire JavaScript - Top JavaScript Talent
# 811      Ask HN: Are there any projects or compilers wh...
# 1046     If you write JavaScript tools or libraries, bu...
# 1093     Rollup.js: A next-generation JavaScript module...
# 1162                  V8 JavaScript Engine: V8 Release 5.4
#                                ...
# 19349      Fotorama, a responsive JavaScript photo gallery
# 19548                   Another Kind of JavaScript Fatigue
# 19610    Lonely programmer detective uncovers the Mozil...
# 19885    Ask HN: Best Practices for CSS in a Modern Jav...
# 20069    Show HN: Parse recipe ingredients using JavaSc...
# Name: title, Length: 169, dtype: object
# 1 Show HN: Hire JavaScript - Top JavaScript Talent
# 2 Ask HN: Are there any projects or compilers which convert JavaScript to Java?
# 3 If you write JavaScript tools or libraries, bundle your code before publishing
# 4 Rollup.js: A next-generation JavaScript module bundler
# ...
